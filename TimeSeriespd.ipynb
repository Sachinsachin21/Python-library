# %% [markdown]
# <a href="https://colab.research.google.com/github/Sachinsachin21/Python-library/blob/main/TimeSeriespd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
s = pd.read_csv("temp.csv",parse_dates=["datetime"],index_col="datetime")
s.head()
# Out:
#                        LA   NY
# datetime
# 2013-01-01 00:00:00  11.7 -1.1
# 2013-01-01 01:00:00  10.7 -1.7
# 2013-01-01 02:00:00   9.9 -2.0
# 2013-01-01 03:00:00   9.3 -2.1
# 2013-01-01 04:00:00   8.8 -2.3

# %%
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 35064 entries, 2013-01-01 00:00:00 to 2016-12-31 23:00:00
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   LA      35062 non-null  float64
#  1   NY      35064 non-null  float64
# dtypes: float64(2)
# memory usage: 1.8 MB

# %%
s.iloc[0,0]
# Out:
# 11.7

# %%
s.index
# Out:
# DatetimeIndex(['2013-01-01 00:00:00', '2013-01-01 01:00:00',
#                '2013-01-01 02:00:00', '2013-01-01 03:00:00',
#                '2013-01-01 04:00:00', '2013-01-01 05:00:00',
#                '2013-01-01 06:00:00', '2013-01-01 07:00:00',
#                '2013-01-01 08:00:00', '2013-01-01 09:00:00',
#                ...
#                '2016-12-31 14:00:00', '2016-12-31 15:00:00',
#                '2016-12-31 16:00:00', '2016-12-31 17:00:00',
#                '2016-12-31 18:00:00', '2016-12-31 19:00:00',
#                '2016-12-31 20:00:00', '2016-12-31 21:00:00',
#                '2016-12-31 22:00:00', '2016-12-31 23:00:00'],
#               dtype='datetime64[ns]', name='datetime', length=35064, freq=None)

# %%
s.index[1]
# Out:
# Timestamp('2013-01-01 01:00:00')

# %%
s.shape
# Out:
# (35064, 2)

# %%
p = pd.read_csv("temp.csv")
p.head()
# Out:
#               datetime    LA   NY
# 0  2013-01-01 00:00:00  11.7 -1.1
# 1  2013-01-01 01:00:00  10.7 -1.7
# 2  2013-01-01 02:00:00   9.9 -2.0
# 3  2013-01-01 03:00:00   9.3 -2.1
# 4  2013-01-01 04:00:00   8.8 -2.3

# %%
p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  35064 non-null  object
#  1   LA        35062 non-null  float64
#  2   NY        35064 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 821.9+ KB

# %%
p.datetime[1]
# Out:
# '2013-01-01 01:00:00'

# %%
pd.to_datetime(p.datetime)                  #1st mtd to convert datetime
# Out:
# 0       2013-01-01 00:00:00
# 1       2013-01-01 01:00:00
# 2       2013-01-01 02:00:00
# 3       2013-01-01 03:00:00
# 4       2013-01-01 04:00:00
#                 ...
# 35059   2016-12-31 19:00:00
# 35060   2016-12-31 20:00:00
# 35061   2016-12-31 21:00:00
# 35062   2016-12-31 22:00:00
# 35063   2016-12-31 23:00:00
# Name: datetime, Length: 35064, dtype: datetime64[ns]

# %%
p1=p.set_index(pd.to_datetime(p.datetime)).drop("datetime",axis=1)

# %%
p1.head()
# Out:
#                        LA   NY
# datetime
# 2013-01-01 00:00:00  11.7 -1.1
# 2013-01-01 01:00:00  10.7 -1.7
# 2013-01-01 02:00:00   9.9 -2.0
# 2013-01-01 03:00:00   9.3 -2.1
# 2013-01-01 04:00:00   8.8 -2.3

# %%
p1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 35064 entries, 2013-01-01 00:00:00 to 2016-12-31 23:00:00
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   LA      35062 non-null  float64
#  1   NY      35064 non-null  float64
# dtypes: float64(2)
# memory usage: 821.8 KB

# %%
p1.index[777]
# Out:
# Timestamp('2013-02-02 09:00:00')

# %%
p1.shape
# Out:
# (35064, 2)

# %%
pd.to_datetime("May 2012 12")
pd.to_datetime("2020 6 12")
pd.to_datetime("2013-10-5")
pd.to_datetime("2013/10/5")
pd.to_datetime("20220520")
# Out:
# Timestamp('2022-05-20 00:00:00')

# %%
p1.isna().all()
# Out:
# LA    False
# NY    False
# dtype: bool

# %%
p1.describe()
# Out:
#                  LA            NY
# count  35062.000000  35064.000000
# mean      17.486016     12.068269
# std        6.640666     10.466832
# min       -6.600000    -22.400000
# 25%       12.900000      3.900000
# 50%       17.200000     12.500000
# 75%       21.900000     20.600000
# max       42.300000     37.100000

# %%
p1.LA.value_counts()
# Out:
# LA
#  16.2    238
#  16.7    237
#  15.2    234
#  18.2    231
#  16.6    228
#         ...
# -5.9       1
# -6.5       1
# -6.6       1
# -2.2       1
# -3.3       1
# Name: count, Length: 442, dtype: int64

# %%
import matplotlib.pyplot as plt
p1.plot(figsize=(5,3),subplots=True)
plt.show()

# %%
p1.plot(figsize=(5,3),subplots=True,layout=(1,2))
plt.show()                            # layout(row,col)

# %%
p1.plot(figsize=(5,3),subplots=True,layout=(2,1),sharey=True)
plt.show()

# %%
s.loc["2013-04-20 10:00:00"]
# Out:
# LA    13.3
# NY    13.5
# Name: 2013-04-20 10:00:00, dtype: float64

# %%
s.loc["2013 01 01":"2015 12 31"].equals(p1.loc["2015"])
# Out:
# False

# %%
t1 = pd.to_datetime(["2015 12 31 10:00:00","2015 12 31 12:00:00"])

# %%
p1.loc[t1]
# Out:
#                       LA   NY
# 2015-12-31 10:00:00  5.5  6.3
# 2015-12-31 12:00:00  4.9  6.3

# %%
pd.date_range(start="2015 07 01",end="2015 07 31")
# Out:
# DatetimeIndex(['2015-07-01', '2015-07-02', '2015-07-03', '2015-07-04',
#                '2015-07-05', '2015-07-06', '2015-07-07', '2015-07-08',
#                '2015-07-09', '2015-07-10', '2015-07-11', '2015-07-12',
#                '2015-07-13', '2015-07-14', '2015-07-15', '2015-07-16',
#                '2015-07-17', '2015-07-18', '2015-07-19', '2015-07-20',
#                '2015-07-21', '2015-07-22', '2015-07-23', '2015-07-24',
#                '2015-07-25', '2015-07-26', '2015-07-27', '2015-07-28',
#                '2015-07-29', '2015-07-30', '2015-07-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start="2015 04 01",periods=31,freq="D")
# Out:
# DatetimeIndex(['2015-04-01', '2015-04-02', '2015-04-03', '2015-04-04',
#                '2015-04-05', '2015-04-06', '2015-04-07', '2015-04-08',
#                '2015-04-09', '2015-04-10', '2015-04-11', '2015-04-12',
#                '2015-04-13', '2015-04-14', '2015-04-15', '2015-04-16',
#                '2015-04-17', '2015-04-18', '2015-04-19', '2015-04-20',
#                '2015-04-21', '2015-04-22', '2015-04-23', '2015-04-24',
#                '2015-04-25', '2015-04-26', '2015-04-27', '2015-04-28',
#                '2015-04-29', '2015-04-30', '2015-05-01'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(end="2015 04 01",periods=31,freq="B")
# Out:
# DatetimeIndex(['2015-02-18', '2015-02-19', '2015-02-20', '2015-02-23',
#                '2015-02-24', '2015-02-25', '2015-02-26', '2015-02-27',
#                '2015-03-02', '2015-03-03', '2015-03-04', '2015-03-05',
#                '2015-03-06', '2015-03-09', '2015-03-10', '2015-03-11',
#                '2015-03-12', '2015-03-13', '2015-03-16', '2015-03-17',
#                '2015-03-18', '2015-03-19', '2015-03-20', '2015-03-23',
#                '2015-03-24', '2015-03-25', '2015-03-26', '2015-03-27',
#                '2015-03-30', '2015-03-31', '2015-04-01'],
#               dtype='datetime64[ns]', freq='B')

# %%
pd.date_range(start="2015 04 01",periods=10 ,freq="7H")
# Out:
# DatetimeIndex(['2015-04-01 00:00:00', '2015-04-01 07:00:00',
#                '2015-04-01 14:00:00', '2015-04-01 21:00:00',
#                '2015-04-02 04:00:00', '2015-04-02 11:00:00',
#                '2015-04-02 18:00:00', '2015-04-03 01:00:00',
#                '2015-04-03 08:00:00', '2015-04-03 15:00:00'],
#               dtype='datetime64[ns]', freq='7H')

# %%
pd.date_range(start="2015 04 01",periods=7,freq="W")
# Out:
# DatetimeIndex(['2015-04-05', '2015-04-12', '2015-04-19', '2015-04-26',
#                '2015-05-03', '2015-05-10', '2015-05-17'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
pd.date_range(end="2015 07 01",periods=7,freq="W-Wed")
# Out:
# DatetimeIndex(['2015-05-20', '2015-05-27', '2015-06-03', '2015-06-10',
#                '2015-06-17', '2015-06-24', '2015-07-01'],
#               dtype='datetime64[ns]', freq='W-WED')

# %%
pd.date_range(start="2015 07 01",periods=7,freq="M")
# Out:
# DatetimeIndex(['2015-07-31', '2015-08-31', '2015-09-30', '2015-10-31',
#                '2015-11-30', '2015-12-31', '2016-01-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
pd.date_range(end="2015 07 01",periods=7,freq="MS")
# Out:
# DatetimeIndex(['2015-01-01', '2015-02-01', '2015-03-01', '2015-04-01',
#                '2015-05-01', '2015-06-01', '2015-07-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
pd.date_range(start="2015 07 14",periods=7,freq= pd.DateOffset(months=1))
# Out:
# DatetimeIndex(['2015-07-14', '2015-08-14', '2015-09-14', '2015-10-14',
#                '2015-11-14', '2015-12-14', '2016-01-14'],
#               dtype='datetime64[ns]', freq='<DateOffset: months=1>')

# %%
pd.date_range(start="2015 03 01",periods=7,freq="Q")
# Out:
# DatetimeIndex(['2015-03-31', '2015-06-30', '2015-09-30', '2015-12-31',
#                '2016-03-31', '2016-06-30', '2016-09-30'],
#               dtype='datetime64[ns]', freq='Q-DEC')

# %%
pd.date_range(end="2015 07 01",periods=7,freq="QS")
# Out:
# DatetimeIndex(['2014-01-01', '2014-04-01', '2014-07-01', '2014-10-01',
#                '2015-01-01', '2015-04-01', '2015-07-01'],
#               dtype='datetime64[ns]', freq='QS-JAN')

# %%
pd.date_range(start="2015 07 01",periods=7,freq="QS-may")
# Out:
# DatetimeIndex(['2015-08-01', '2015-11-01', '2016-02-01', '2016-05-01',
#                '2016-08-01', '2016-11-01', '2017-02-01'],
#               dtype='datetime64[ns]', freq='QS-MAY')

# %%
pd.date_range(end="2015 07 01",periods=7,freq="AS")
# Out:
# DatetimeIndex(['2009-01-01', '2010-01-01', '2011-01-01', '2012-01-01',
#                '2013-01-01', '2014-01-01', '2015-01-01'],
#               dtype='datetime64[ns]', freq='AS-JAN')

# %%
pd.date_range(end="2015 07 01",periods=7,freq="A")
# Out:
# DatetimeIndex(['2008-12-31', '2009-12-31', '2010-12-31', '2011-12-31',
#                '2012-12-31', '2013-12-31', '2014-12-31'],
#               dtype='datetime64[ns]', freq='A-DEC')

# %%
pd.date_range(end="2015 07 01",periods=7,freq="A-jun")
# Out:
# DatetimeIndex(['2009-06-30', '2010-06-30', '2011-06-30', '2012-06-30',
#                '2013-06-30', '2014-06-30', '2015-06-30'],
#               dtype='datetime64[ns]', freq='A-JUN')

# %%
pd.date_range(start="2015 07 14",periods=7,freq= pd.DateOffset(years=1))
# Out:
# DatetimeIndex(['2015-07-14', '2016-07-14', '2017-07-14', '2018-07-14',
#                '2019-07-14', '2020-07-14', '2021-07-14'],
#               dtype='datetime64[ns]', freq='<DateOffset: years=1>')

# %%
pd.date_range(start="2015 07 14",periods=7,freq="3D7H")
# Out:
# DatetimeIndex(['2015-07-14 00:00:00', '2015-07-17 07:00:00',
#                '2015-07-20 14:00:00', '2015-07-23 21:00:00',
#                '2015-07-27 04:00:00', '2015-07-30 11:00:00',
#                '2015-08-02 18:00:00'],
#               dtype='datetime64[ns]', freq='79H')

# %%
import seaborn as sns

# %%
s.resample("D").first()
# Out:
#               LA    NY
# datetime
# 2013-01-01  11.7  -1.1
# 2013-01-02  13.2   2.6
# 2013-01-03  15.1   0.3
# 2013-01-04  16.3  -1.2
# 2013-01-05  18.1  -1.2
# ...          ...   ...
# 2016-12-27  15.1   4.1
# 2016-12-28  19.9  11.2
# 2016-12-29  23.3   2.1
# 2016-12-30  25.5   3.0
# 2016-12-31  15.7   0.8
#
# [1461 rows x 2 columns]

# %%
len(list(s.resample("D")))
list(s.resample("D"))[7][1]
# Out:
#                        LA   NY
# datetime
# 2013-01-08 00:00:00  12.0  5.1
# 2013-01-08 01:00:00  11.3  5.2
# 2013-01-08 02:00:00  10.9  5.1
# 2013-01-08 03:00:00  10.8  4.4
# 2013-01-08 04:00:00  10.5  3.7
# 2013-01-08 05:00:00   9.8  3.2
# 2013-01-08 06:00:00   9.9  2.6
# 2013-01-08 07:00:00   9.3  2.3
# 2013-01-08 08:00:00   8.9  1.5
# 2013-01-08 09:00:00   8.8  1.9
# 2013-01-08 10:00:00   7.8  1.5
# 2013-01-08 11:00:00   7.9  0.9
# 2013-01-08 12:00:00   8.2  1.1
# 2013-01-08 13:00:00   7.8  2.6
# 2013-01-08 14:00:00   7.3  5.0
# 2013-01-08 15:00:00   6.9  5.8
# 2013-01-08 16:00:00   8.6  6.7
# 2013-01-08 17:00:00  11.7  7.3
# 2013-01-08 18:00:00  14.5  7.5
# 2013-01-08 19:00:00  16.2  8.0
# 2013-01-08 20:00:00  18.4  7.5
# 2013-01-08 21:00:00  17.5  5.4
# 2013-01-08 22:00:00  18.1  4.1
# 2013-01-08 23:00:00  18.2  2.5

# %%
s.resample("M").last()
# Out:
#               LA    NY
# datetime
# 2013-01-31  18.2  12.4
# 2013-02-28  22.4   7.2
# 2013-03-31  20.5  12.5
# 2013-04-30  21.5  13.0
# 2013-05-31  25.7  31.2
# 2013-06-30  31.2  26.3
# 2013-07-31  25.0  26.0
# 2013-08-31  29.5  28.1
# 2013-09-30  27.5  17.7
# 2013-10-31  18.4  19.0
# 2013-11-30  23.4   1.8
# 2013-12-31  20.8  -0.9
# 2014-01-31  15.8   2.3
# 2014-02-28  12.8  -6.2
# 2014-03-31  17.1  11.0
# 2014-04-30  25.3  11.2
# 2014-05-31  26.3  19.7
# 2014-06-30  28.5  29.0
# 2014-07-31  30.2  25.6
# 2014-08-31  30.2  25.4
# 2014-09-30  25.5  18.4
# 2014-10-31  18.7  11.2
# 2014-11-30  12.9   8.5
# 2014-12-31   5.6  -4.5
# 2015-01-31  17.8  -6.2
# 2015-02-28  10.5 -11.5
# 2015-03-31  24.3   7.2
# 2015-04-30  28.1  13.8
# 2015-05-31  25.5  19.9
# 2015-06-30  31.1  24.2
# 2015-07-31  30.9  30.4
# 2015-08-31  28.7  30.4
# 2015-09-30  31.3  19.6
# 2015-10-31  28.1  10.5
# 2015-11-30  16.3   5.9
# 2015-12-31  16.8   6.2
# 2016-01-31  13.4   7.2
# 2016-02-29  23.6  11.9
# ...

# %%
s.resample("m").mean()
# Out:
#                    LA         NY
# datetime
# 2013-01-31  11.596237   1.129570
# 2013-02-28  12.587202   0.617857
# 2013-03-31  15.069946   3.719220
# 2013-04-30  16.487361  10.699306
# 2013-05-31  19.005780  15.824328
# 2013-06-30  19.905417  22.225694
# 2013-07-31  22.093952  26.329704
# 2013-08-31  21.513172  22.480376
# 2013-09-30  22.404861  18.291806
# 2013-10-31  16.620430  14.335215
# 2013-11-30  15.107917   7.111944
# 2013-12-31  13.416935   2.776210
# 2014-01-31  16.247715  -2.210349
# 2014-02-28  14.326637  -1.596280
# 2014-03-31  15.836156   1.994758
# 2014-04-30  16.783472  10.128611
# 2014-05-31  20.041398  16.829167
# 2014-06-30  19.810556  21.784861
# 2014-07-31  23.056183  24.019624
# 2014-08-31  22.146102  21.848387
# 2014-09-30  21.620278  19.267222
# 2014-10-31  16.968280  14.265860
# 2014-11-30  11.322083   5.719167
# 2014-12-31   8.523925   3.513844
# 2015-01-31   9.527016  -4.179301
# 2015-02-28  11.587649  -7.239732
# 2015-03-31  14.465995   1.020161
# ...

# %%
s.resample("YS").last().mean()
# Out:
# LA    13.775
# NY     1.575
# dtype: float64

# %%
s.resample("MS",kind="timestamp").mean()
# Out:
#                    LA         NY
# datetime
# 2013-01-01  11.596237   1.129570
# 2013-02-01  12.587202   0.617857
# 2013-03-01  15.069946   3.719220
# 2013-04-01  16.487361  10.699306
# 2013-05-01  19.005780  15.824328
# 2013-06-01  19.905417  22.225694
# 2013-07-01  22.093952  26.329704
# 2013-08-01  21.513172  22.480376
# 2013-09-01  22.404861  18.291806
# 2013-10-01  16.620430  14.335215
# 2013-11-01  15.107917   7.111944
# 2013-12-01  13.416935   2.776210
# 2014-01-01  16.247715  -2.210349
# 2014-02-01  14.326637  -1.596280
# 2014-03-01  15.836156   1.994758
# 2014-04-01  16.783472  10.128611
# 2014-05-01  20.041398  16.829167
# 2014-06-01  19.810556  21.784861
# 2014-07-01  23.056183  24.019624
# 2014-08-01  22.146102  21.848387
# 2014-09-01  21.620278  19.267222
# 2014-10-01  16.968280  14.265860
# 2014-11-01  11.322083   5.719167
# 2014-12-01   8.523925   3.513844
# 2015-01-01   9.527016  -4.179301
# 2015-02-01  11.587649  -7.239732
# 2015-03-01  14.465995   1.020161
# ...

# %%
s.resample("Y",kind="timestamp").mean()
# Out:
#                    LA         NY
# datetime
# 2013-12-31  17.174229  12.196153
# 2014-12-31  17.245616  11.370959
# 2015-12-31  17.191530  11.795194
# 2016-12-31  18.330305  12.908470

# %%
s.resample("Y",kind="period").mean()
# Out:
#                  LA         NY
# datetime
# 2013      17.174229  12.196153
# 2014      17.245616  11.370959
# 2015      17.191530  11.795194
# 2016      18.330305  12.908470

# %%
s.resample("A",kind="period").mean()
# Out:
#                  LA         NY
# datetime
# 2013      17.174229  12.196153
# 2014      17.245616  11.370959
# 2015      17.191530  11.795194
# 2016      18.330305  12.908470

# %%
w1 = s.resample("M",kind="period").mean()
w1
# Out:
#                  LA         NY
# datetime
# 2013-01   11.596237   1.129570
# 2013-02   12.587202   0.617857
# 2013-03   15.069946   3.719220
# 2013-04   16.487361  10.699306
# 2013-05   19.005780  15.824328
# 2013-06   19.905417  22.225694
# 2013-07   22.093952  26.329704
# 2013-08   21.513172  22.480376
# 2013-09   22.404861  18.291806
# 2013-10   16.620430  14.335215
# 2013-11   15.107917   7.111944
# 2013-12   13.416935   2.776210
# 2014-01   16.247715  -2.210349
# 2014-02   14.326637  -1.596280
# 2014-03   15.836156   1.994758
# 2014-04   16.783472  10.128611
# 2014-05   20.041398  16.829167
# 2014-06   19.810556  21.784861
# 2014-07   23.056183  24.019624
# 2014-08   22.146102  21.848387
# 2014-09   21.620278  19.267222
# 2014-10   16.968280  14.265860
# 2014-11   11.322083   5.719167
# 2014-12    8.523925   3.513844
# 2015-01    9.527016  -4.179301
# 2015-02   11.587649  -7.239732
# 2015-03   14.465995   1.020161
# 2015-04   13.527917  10.180417
# ...

# %%
w1.shape
# Out:
# (48, 2)

# %%
w1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 48 entries, 2013-01 to 2016-12
# Freq: M
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   LA      48 non-null     float64
#  1   NY      48 non-null     float64
# dtypes: float64(2)
# memory usage: 1.1 KB

# %%
w1.index[1]
# Out:
# Period('2013-02', 'M')

# %%
w1.plot(figsize=(6,4),fontsize=8)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
s.plot(figsize=(8,6),fontsize=8)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
w1.to_timestamp(how="start")
# Out:
#                    LA         NY
# datetime
# 2013-01-01  11.596237   1.129570
# 2013-02-01  12.587202   0.617857
# 2013-03-01  15.069946   3.719220
# 2013-04-01  16.487361  10.699306
# 2013-05-01  19.005780  15.824328
# 2013-06-01  19.905417  22.225694
# 2013-07-01  22.093952  26.329704
# 2013-08-01  21.513172  22.480376
# 2013-09-01  22.404861  18.291806
# 2013-10-01  16.620430  14.335215
# 2013-11-01  15.107917   7.111944
# 2013-12-01  13.416935   2.776210
# 2014-01-01  16.247715  -2.210349
# 2014-02-01  14.326637  -1.596280
# 2014-03-01  15.836156   1.994758
# 2014-04-01  16.783472  10.128611
# 2014-05-01  20.041398  16.829167
# 2014-06-01  19.810556  21.784861
# 2014-07-01  23.056183  24.019624
# 2014-08-01  22.146102  21.848387
# 2014-09-01  21.620278  19.267222
# 2014-10-01  16.968280  14.265860
# 2014-11-01  11.322083   5.719167
# 2014-12-01   8.523925   3.513844
# 2015-01-01   9.527016  -4.179301
# 2015-02-01  11.587649  -7.239732
# 2015-03-01  14.465995   1.020161
# ...

# %%
bukz = pd.date_range(start="2004 07 29",periods=20,freq=pd.DateOffset(years=1))
bukz
# Out:
# DatetimeIndex(['2004-07-29', '2005-07-29', '2006-07-29', '2007-07-29',
#                '2008-07-29', '2009-07-29', '2010-07-29', '2011-07-29',
#                '2012-07-29', '2013-07-29', '2014-07-29', '2015-07-29',
#                '2016-07-29', '2017-07-29', '2018-07-29', '2019-07-29',
#                '2020-07-29', '2021-07-29', '2022-07-29', '2023-07-29'],
#               dtype='datetime64[ns]', freq='<DateOffset: years=1>')

# %%
boo = pd.date_range(start="2005 01 31",periods=21,freq=pd.DateOffset(years=1))
boo
# Out:
# DatetimeIndex(['2005-01-31', '2006-01-31', '2007-01-31', '2008-01-31',
#                '2009-01-31', '2010-01-31', '2011-01-31', '2012-01-31',
#                '2013-01-31', '2014-01-31', '2015-01-31', '2016-01-31',
#                '2017-01-31', '2018-01-31', '2019-01-31', '2020-01-31',
#                '2021-01-31', '2022-01-31', '2023-01-31', '2024-01-31',
#                '2025-01-31'],
#               dtype='datetime64[ns]', freq='<DateOffset: years=1>')

# %%
boo.value_counts().sum()
# Out:
# 21

# %%
w1.reindex()
# Out:
#                  LA         NY
# datetime
# 2013-01   11.596237   1.129570
# 2013-02   12.587202   0.617857
# 2013-03   15.069946   3.719220
# 2013-04   16.487361  10.699306
# 2013-05   19.005780  15.824328
# 2013-06   19.905417  22.225694
# 2013-07   22.093952  26.329704
# 2013-08   21.513172  22.480376
# 2013-09   22.404861  18.291806
# 2013-10   16.620430  14.335215
# 2013-11   15.107917   7.111944
# 2013-12   13.416935   2.776210
# 2014-01   16.247715  -2.210349
# 2014-02   14.326637  -1.596280
# 2014-03   15.836156   1.994758
# 2014-04   16.783472  10.128611
# 2014-05   20.041398  16.829167
# 2014-06   19.810556  21.784861
# 2014-07   23.056183  24.019624
# 2014-08   22.146102  21.848387
# 2014-09   21.620278  19.267222
# 2014-10   16.968280  14.265860
# 2014-11   11.322083   5.719167
# 2014-12    8.523925   3.513844
# 2015-01    9.527016  -4.179301
# 2015-02   11.587649  -7.239732
# 2015-03   14.465995   1.020161
# 2015-04   13.527917  10.180417
# ...
